# %%
import numpy as np
import pandas as pd
import requests
import pprint
import json
r = requests.get("https://api.opendota.com/api/players/107828036/matches")
print(r.text)
# Out:
# [{"match_id":5534351469,"player_slot":3,"radiant_win":true,"duration":2100,"game_mode":22,"lobby_type":0,"hero_id":40,"start_time":1595652178,"version":null,"kills":5,"deaths":12,"assists":18,"skill":1,"leaver_status":0,"party_size":2},{"match_id":5534305959,"player_slot":131,"radiant_win":false,"duration":2093,"game_mode":22,"lobby_type":0,"hero_id":108,"start_time":1595649714,"version":21,"kills":6,"deaths":7,"assists":23,"skill":1,"leaver_status":0,"party_size":2},{"match_id":5523227650,"player_slot":0,"radiant_win":false,"duration":3327,"game_mode":22,"lobby_type":0,"hero_id":35,"start_time":1595137736,"version":null,"kills":16,"deaths":11,"assists":7,"skill":null,"leaver_status":0,"party_size":2},{"match_id":5523158233,"player_slot":2,"radiant_win":true,"duration":2461,"game_mode":22,"lobby_type":0,"hero_id":35,"start_time":1595134867,"version":null,"kills":12,"deaths":6,"assists":13,"skill":1,"leaver_status":0,"party_size":2},{"match_id":5523096833,"player_slot":130,"radiant_win":false,"duration":2237,"game_mode":22,"lobby_type":0,"hero_id":42,"start_time":1595132099,"version":null,"kills":9,"deaths":4,"assists":19,"skill":1,"leaver_status":0,"party_size":2},{"match_id":5518579130,"player_slot":128,"radiant_win":true,"duration":1888,"game_mode":22,"lobby_type":0,"hero_id":84,"start_time":1594959342,"version":null,"kills":5,"deaths":8,"assists":11,"skill":null,"leaver_status":0,"party_size":null},{"match_id":5518524219,"player_slot":0,"radiant_win":false,"duration":2535,"game_mode":22,"lobby_type":0,"hero_id":35,"start_time":1594956484,"version":null,"kills":4,"deaths":7,"assists":12,"skill":1,"leaver_status":0,"party_size":2},{"match_id":5509311076,"player_slot":131,"radiant_win":true,"duration":2841,"game_mode":22,"lobby_type":0,"hero_id":35,"start_time":1594528305,"version":null,"kills":4,"deaths":7,"assists":7,"skill":1,"leaver_status":0,"party_size":2},{"match_id":5509272068,"player_slot":2,"radiant_win":true,"duration":1960,"game_mode":22,"lobby_type":0,"hero_id":41,"start_time":1594525607,"version":null,"kills":8,"deaths":2,"assists":13,"skill":1,"leaver_status":0,"party_size":2},{"match_id":5509227909,"player_slot":131,"radiant_win":true,"duration":2670,"game_mode":22,"lobby_type":0,"hero_id":47,"start_time":1594522478,"version":21,"kills":5,"deaths":11,"assists":13,"skill":1,"leaver_status":0,"party_size":2},{"match_id":5493989048,"player_slot":3,"radiant_win":false,"duration":2156,"game_mode":22,"lobby_type":0,"hero_id":35,"start_time":1593574186,"version":null,"kills":4,"deaths":9,"assists":3,"skill":1,"leaver_status":0,"party_size":2},{"match_id":5493953277,"player_slot":1,"radiant_win":false,"duration":2587,"game_mode":22,"lobby_type":0,"hero_id":35,"start_time":1593571251,"version":null,"kills":11,"deaths":7,"assists":14,"skill":null,"leaver_status":0,"party_size":2},{"match_id":5492632804,"player_slot":131,"radiant_win":true,"duration":2095,"game_mode":22,"lobby_type":0,"hero_id":6,"start_time":1593490815,"version":null,"kills":6,"deaths":9,"assists":8,"skill":1,"leaver_status":0,"party_size":2},{"match_id":5492599338,"player_slot":0,"radiant_win":true,"duration":2268,"game_mode":22,"lobby_type":0,"hero_id":6,"start_time":1593488106,"version":null,"kills":9,"deaths":3,"assists":4,"skill":1,"leaver_status":0,"party_size":2},{"match_id":5492554658,"player_slot":0,"radiant_win":true,"duration":2999,"game_mode":22,"lobby_type":0,"hero_id":42,"start_time":1593484434,"version":null,"kills":6,"deaths":7,"assists":16,"skill":1,"leaver_status":0,"party_size":2},{"match_id":5489790063,"player_slot":0,"radiant_win":false,"duration":2809,"game_mode":22,"lobby_type":0,"hero_id":8,"start_time":1593317110,"version":21,"kills":6,"deaths":12,"assists":5,"skill":1,"leaver_status":0,"party_size":2},{"match_id":5489757734,"player_slot":128,"radiant_win":true,"duration":1849,"game_mode":22,"lobby_type":0,"hero_id":20,"start_time":1593314601,"version":null,"kills":3,"deaths":13,"assists":15,"skill":1,"leaver_status":0,"party_siz ...

# %%
data = pprint.pprint(json.loads(r.text))
# Out:
# [{'assists': 18,
#   'deaths': 12,
#   'duration': 2100,
#   'game_mode': 22,
#   'hero_id': 40,
#   'kills': 5,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5534351469,
#   'party_size': 2,
#   'player_slot': 3,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1595652178,
#   'version': None},
#  {'assists': 23,
#   'deaths': 7,
#   'duration': 2093,
#   'game_mode': 22,
#   'hero_id': 108,
#   'kills': 6,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5534305959,
#   'party_size': 2,
#   'player_slot': 131,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1595649714,
#   'version': 21},
#  {'assists': 7,
#   'deaths': 11,
#   'duration': 3327,
#   'game_mode': 22,
#   'hero_id': 35,
#   'kills': 16,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5523227650,
#   'party_size': 2,
#   'player_slot': 0,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1595137736,
#   'version': None},
#  {'assists': 13,
#   'deaths': 6,
#   'duration': 2461,
#   'game_mode': 22,
#   'hero_id': 35,
#   'kills': 12,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5523158233,
#   'party_size': 2,
#   'player_slot': 2,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1595134867,
#   'version': None},
#  {'assists': 19,
#   'deaths': 4,
#   'duration': 2237,
#   'game_mode': 22,
#   'hero_id': 42,
#   'kills': 9,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5523096833,
#   'party_size': 2,
#   'player_slot': 130,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1595132099,
#   'version': None},
#  {'assists': 11,
#   'deaths': 8,
#   'duration': 1888,
#   'game_mode': 22,
#   'hero_id': 84,
#   'kills': 5,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5518579130,
#   'party_size': None,
#   'player_slot': 128,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1594959342,
#   'version': None},
#  {'assists': 12,
#   'deaths': 7,
#   'duration': 2535,
#   'game_mode': 22,
#   'hero_id': 35,
#   'kills': 4,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5518524219,
#   'party_size': 2,
#   'player_slot': 0,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1594956484,
#   'version': None},
#  {'assists': 7,
#   'deaths': 7,
#   'duration': 2841,
#   'game_mode': 22,
#   'hero_id': 35,
#   'kills': 4,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5509311076,
#   'party_size': 2,
#   'player_slot': 131,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1594528305,
#   'version': None},
#  {'assists': 13,
#   'deaths': 2,
#   'duration': 1960,
#   'game_mode': 22,
#   'hero_id': 41,
#   'kills': 8,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5509272068,
#   'party_size': 2,
#   'player_slot': 2,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1594525607,
#   'version': None},
#  {'assists': 13,
#   'deaths': 11,
#   'duration': 2670,
#   'game_mode': 22,
#   'hero_id': 47,
#   'kills': 5,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5509227909,
#   'party_size': 2,
#   'player_slot': 131,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1594522478,
#   'version': 21},
#  {'assists': 3,
#   'deaths': 9,
#   'duration': 2156,
#   'game_mode': 22,
#   'hero_id': 35,
#   'kills': 4,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5493989048,
#   'party_size': 2,
#   'player_slot': 3,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1593574186,
#   'version': None},
#  {'assists': 14,
#   'deaths': 7,
#   'duration': 2587,
#   'game_mode': 22,
#   'hero_id': 35,
#   'kills': 11,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5493953277,
#   'party_size': 2,
#   'player_slot': 1,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1593571251,
#   'version': None},
#  {'assists': 8,
#   'deaths': 9,
#   'duration': 2095,
#   'game_mode': 22,
#   'hero_id': 6,
#   'kills': 6,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5492632804,
#   'party_size': 2,
#   'player_slot': 131,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1593490815,
#   'version': None},
#  {'assists': 4,
#   'deaths': 3,
#   'duration': 2268,
#   'game_mode': 22,
#   'hero_id': 6,
#   'kills': 9,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5492599338,
#   'party_size': 2,
#   'player_slot': 0,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1593488106,
#   'version': None},
#  {'assists': 16,
#   'deaths': 7,
#   'duration': 2999,
#   'game_mode': 22,
#   'hero_id': 42,
#   'kills': 6,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5492554658,
#   'party_size': 2,
#   'player_slot': 0,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1593484434,
#   'version': None},
#  {'assists': 5,
#   'deaths': 12,
#   'duration': 2809,
#   'game_mode': 22,
#   'hero_id': 8,
#   'kills': 6,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5489790063,
#   'party_size': 2,
#   'player_slot': 0,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1593317110,
#   'version': 21},
#  {'assists': 15,
#   'deaths': 13,
#   'duration': 1849,
#   'game_mode': 22,
#   'hero_id': 20,
#   'kills': 3,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5489757734,
#   'party_size': 2,
#   'player_slot': 128,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1593314601,
#   'version': None},
#  {'assists': 7,
#   'deaths': 7,
#   'duration': 2173,
#   'game_mode': 22,
#   'hero_id': 64,
#   'kills': 4,
#   'leaver_status': 0,
#   'lobby_type': 7,
#   'match_id': 5489491053,
#   'party_size': 3,
#   'player_slot': 1,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1593291154,
#   'version': None},
#  {'assists': 0,
#   'deaths': 10,
#   'duration': 1601,
#   'game_mode': 22,
#   'hero_id': 121,
#   'kills': 4,
#   'leaver_status': 0,
#   'lobby_type': 7,
#   'match_id': 5489458954,
#   'party_size': 2,
#   'player_slot': 130,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1593289070,
#   'version': None},
#  {'assists': 7,
#   'deaths': 1,
#   'duration': 1943,
#   'game_mode': 22,
#   'hero_id': 70,
#   'kills': 20,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5488431012,
#   'party_size': None,
#   'player_slot': 3,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1593237188,
#   'version': None},
#  {'assists': 30,
#   'deaths': 13,
#   'duration': 3389,
#   'game_mode': 22,
#   'hero_id': 64,
#   'kills': 7,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5488365579,
#   'party_size': 2,
#   'player_slot': 130,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1593232951,
#   'version': None},
#  {'assists': 17,
#   'deaths': 5,
#   'duration': 2637,
#   'game_mode': 22,
#   'hero_id': 42,
#   'kills': 14,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5488322506,
#   'party_size': 2,
#   'player_slot': 131,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1593229862,
#   'version': None},
#  {'assists': 20,
#   'deaths': 6,
#   'duration': 2646,
#   'game_mode': 22,
#   'hero_id': 35,
#   'kills': 17,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5487003651,
#   'party_size': 2,
#   'player_slot': 131,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1593150084,
#   'version': None},
#  {'assists': 17,
#   'deaths': 3,
#   'duration': 2195,
#   'game_mode': 22,
#   'hero_id': 39,
#   'kills': 12,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5486964448,
#   'party_size': 2,
#   'player_slot': 2,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1593147259,
#   'version': None},
#  {'assists': 24,
#   'deaths': 8,
#   'duration': 2848,
#   'game_mode': 22,
#   'hero_id': 40,
#   'kills': 12,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5486919184,
#   'party_size': 2,
#   'player_slot': 130,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1593143708,
#   'version': None},
#  {'assists': 5,
#   'deaths': 8,
#   'duration': 2121,
#   'game_mode': 22,
#   'hero_id': 39,
#   'kills': 13,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5485597724,
#   'party_size': 2,
#   'player_slot': 130,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1593061660,
#   'version': None},
#  {'assists': 8,
#   'deaths': 4,
#   'duration': 1290,
#   'game_mode': 22,
#   'hero_id': 7,
#   'kills': 7,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5485574389,
#   'party_size': 2,
#   'player_slot': 3,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1593059934,
#   'version': None},
#  {'assists': 22,
#   'deaths': 5,
#   'duration': 1903,
#   'game_mode': 22,
#   'hero_id': 23,
#   'kills': 5,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5485543944,
#   'party_size': 2,
#   'player_slot': 129,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1593057543,
#   'version': None},
#  {'assists': 6,
#   'deaths': 11,
#   'duration': 3139,
#   'game_mode': 22,
#   'hero_id': 23,
#   'kills': 9,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5485495413,
#   'party_size': 2,
#   'player_slot': 0,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1593053753,
#   'version': None},
#  {'assists': 4,
#   'deaths': 13,
#   'duration': 1889,
#   'game_mode': 22,
#   'hero_id': 71,
#   'kills': 2,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5484226228,
#   'party_size': 2,
#   'player_slot': 0,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1592972896,
#   'version': None},
#  {'assists': 17,
#   'deaths': 10,
#   'duration': 2571,
#   'game_mode': 22,
#   'hero_id': 71,
#   'kills': 10,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5484192857,
#   'party_size': 2,
#   'player_slot': 129,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1592969957,
#   'version': None},
#  {'assists': 8,
#   'deaths': 6,
#   'duration': 2346,
#   'game_mode': 22,
#   'hero_id': 7,
#   'kills': 10,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5481609063,
#   'party_size': 2,
#   'player_slot': 2,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1592796789,
#   'version': None},
#  {'assists': 9,
#   'deaths': 12,
#   'duration': 2209,
#   'game_mode': 22,
#   'hero_id': 71,
#   'kills': 2,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5481571208,
#   'party_size': 2,
#   'player_slot': 1,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1592793288,
#   'version': None},
#  {'assists': 9,
#   'deaths': 9,
#   'duration': 2476,
#   'game_mode': 22,
#   'hero_id': 8,
#   'kills': 3,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5481542115,
#   'party_size': 2,
#   'player_slot': 128,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1592790478,
#   'version': None},
#  {'assists': 7,
#   'deaths': 9,
#   'duration': 2453,
#   'game_mode': 22,
#   'hero_id': 6,
#   'kills': 9,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5480284431,
#   'party_size': 5,
#   'player_slot': 132,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1592720103,
#   'version': None},
#  {'assists': 4,
#   'deaths': 10,
#   'duration': 2257,
#   'game_mode': 22,
#   'hero_id': 108,
#   'kills': 3,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5480237660,
#   'party_size': 5,
#   'player_slot': 132,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1592717376,
#   'version': 21},
#  {'assists': 47,
#   'deaths': 16,
#   'duration': 4440,
#   'game_mode': 22,
#   'hero_id': 103,
#   'kills': 14,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5480160158,
#   'party_size': 3,
#   'player_slot': 2,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1592712106,
#   'version': 21},
#  {'assists': 11,
#   'deaths': 13,
#   'duration': 2284,
#   'game_mode': 22,
#   'hero_id': 103,
#   'kills': 1,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5480121740,
#   'party_size': 3,
#   'player_slot': 130,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1592709445,
#   'version': 21},
#  {'assists': 21,
#   'deaths': 4,
#   'duration': 2359,
#   'game_mode': 22,
#   'hero_id': 102,
#   'kills': 5,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5480056973,
#   'party_size': 3,
#   'player_slot': 1,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1592704706,
#   'version': None},
#  {'assists': 9,
#   'deaths': 1,
#   'duration': 1757,
#   'game_mode': 22,
#   'hero_id': 70,
#   'kills': 13,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5478685024,
#   'party_size': 2,
#   'player_slot': 3,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1592626923,
#   'version': None},
#  {'assists': 14,
#   'deaths': 3,
#   'duration': 1943,
#   'game_mode': 22,
#   'hero_id': 7,
#   'kills': 6,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5478653720,
#   'party_size': 2,
#   'player_slot': 0,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1592624629,
#   'version': 21},
#  {'assists': 17,
#   'deaths': 9,
#   'duration': 3090,
#   'game_mode': 22,
#   'hero_id': 87,
#   'kills': 5,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5477293473,
#   'party_size': 3,
#   'player_slot': 128,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1592537210,
#   'version': None},
#  {'assists': 15,
#   'deaths': 13,
#   'duration': 2660,
#   'game_mode': 22,
#   'hero_id': 87,
#   'kills': 4,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5477254428,
#   'party_size': 3,
#   'player_slot': 128,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1592534089,
#   'version': None},
#  {'assists': 6,
#   'deaths': 10,
#   'duration': 3072,
#   'game_mode': 22,
#   'hero_id': 26,
#   'kills': 8,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5475917679,
#   'party_size': 5,
#   'player_slot': 128,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1592455503,
#   'version': None},
#  {'assists': 10,
#   'deaths': 2,
#   'duration': 2181,
#   'game_mode': 22,
#   'hero_id': 73,
#   'kills': 13,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5475879579,
#   'party_size': 3,
#   'player_slot': 2,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1592452748,
#   'version': None},
#  {'assists': 20,
#   'deaths': 6,
#   'duration': 2377,
#   'game_mode': 22,
#   'hero_id': 48,
#   'kills': 15,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5475842281,
#   'party_size': 3,
#   'player_slot': 0,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1592449954,
#   'version': None},
#  {'assists': 4,
#   'deaths': 7,
#   'duration': 2424,
#   'game_mode': 22,
#   'hero_id': 37,
#   'kills': 4,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5475801496,
#   'party_size': 2,
#   'player_slot': 131,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1592446855,
#   'version': None},
#  {'assists': 16,
#   'deaths': 6,
#   'duration': 1908,
#   'game_mode': 22,
#   'hero_id': 64,
#   'kills': 5,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5473121456,
#   'party_size': 2,
#   'player_slot': 129,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1592278805,
#   'version': None},
#  {'assists': 11,
#   'deaths': 9,
#   'duration': 2934,
#   'game_mode': 22,
#   'hero_id': 64,
#   'kills': 3,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5473076932,
#   'party_size': 2,
#   'player_slot': 131,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1592275160,
#   'version': None},
#  {'assists': 12,
#   'deaths': 6,
#   'duration': 2814,
#   'game_mode': 22,
#   'hero_id': 39,
#   'kills': 5,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5469778461,
#   'party_size': 3,
#   'player_slot': 0,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1592107024,
#   'version': None},
#  {'assists': 17,
#   'deaths': 6,
#   'duration': 2661,
#   'game_mode': 22,
#   'hero_id': 99,
#   'kills': 19,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5469725931,
#   'party_size': 3,
#   'player_slot': 129,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1592103976,
#   'version': None},
#  {'assists': 20,
#   'deaths': 2,
#   'duration': 1974,
#   'game_mode': 22,
#   'hero_id': 31,
#   'kills': 5,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5469686259,
#   'party_size': 3,
#   'player_slot': 1,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1592101596,
#   'version': None},
#  {'assists': 23,
#   'deaths': 1,
#   'duration': 2324,
#   'game_mode': 22,
#   'hero_id': 67,
#   'kills': 11,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5469643938,
#   'party_size': 2,
#   'player_slot': 131,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1592098743,
#   'version': None},
#  {'assists': 24,
#   'deaths': 2,
#   'duration': 1984,
#   'game_mode': 22,
#   'hero_id': 20,
#   'kills': 5,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5468030831,
#   'party_size': 2,
#   'player_slot': 1,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1592022440,
#   'version': None},
#  {'assists': 18,
#   'deaths': 11,
#   'duration': 2278,
#   'game_mode': 22,
#   'hero_id': 20,
#   'kills': 7,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5467988085,
#   'party_size': 2,
#   'player_slot': 0,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1592019815,
#   'version': None},
#  {'assists': 14,
#   'deaths': 6,
#   'duration': 2190,
#   'game_mode': 22,
#   'hero_id': 7,
#   'kills': 5,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5463215603,
#   'party_size': 2,
#   'player_slot': 3,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1591761701,
#   'version': None},
#  {'assists': 10,
#   'deaths': 9,
#   'duration': 2850,
#   'game_mode': 22,
#   'hero_id': 39,
#   'kills': 13,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5463170756,
#   'party_size': 2,
#   'player_slot': 128,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1591758332,
#   'version': None},
#  {'assists': 9,
#   'deaths': 6,
#   'duration': 2547,
#   'game_mode': 22,
#   'hero_id': 21,
#   'kills': 11,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5460022401,
#   'party_size': 3,
#   'player_slot': 0,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1591592362,
#   'version': None},
#  {'assists': 17,
#   'deaths': 7,
#   'duration': 2797,
#   'game_mode': 22,
#   'hero_id': 108,
#   'kills': 10,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5459977443,
#   'party_size': 3,
#   'player_slot': 2,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1591589227,
#   'version': 21},
#  {'assists': 11,
#   'deaths': 10,
#   'duration': 3111,
#   'game_mode': 22,
#   'hero_id': 58,
#   'kills': 3,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5459929256,
#   'party_size': 2,
#   'player_slot': 3,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1591585742,
#   'version': None},
#  {'assists': 20,
#   'deaths': 5,
#   'duration': 2225,
#   'game_mode': 22,
#   'hero_id': 38,
#   'kills': 5,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5458163515,
#   'party_size': 3,
#   'player_slot': 2,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1591504316,
#   'version': None},
#  {'assists': 15,
#   'deaths': 8,
#   'duration': 2496,
#   'game_mode': 22,
#   'hero_id': 20,
#   'kills': 5,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5458110727,
#   'party_size': 4,
#   'player_slot': 128,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1591501453,
#   'version': None},
#  {'assists': 9,
#   'deaths': 8,
#   'duration': 3190,
#   'game_mode': 22,
#   'hero_id': 12,
#   'kills': 8,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5458043542,
#   'party_size': 5,
#   'player_slot': 128,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1591497558,
#   'version': None},
#  {'assists': 23,
#   'deaths': 6,
#   'duration': 3134,
#   'game_mode': 22,
#   'hero_id': 39,
#   'kills': 10,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5456266958,
#   'party_size': 2,
#   'player_slot': 128,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1591418386,
#   'version': 21},
#  {'assists': 6,
#   'deaths': 1,
#   'duration': 1996,
#   'game_mode': 22,
#   'hero_id': 73,
#   'kills': 13,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5456213903,
#   'party_size': 2,
#   'player_slot': 1,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1591415412,
#   'version': None},
#  {'assists': 9,
#   'deaths': 6,
#   'duration': 2314,
#   'game_mode': 22,
#   'hero_id': 67,
#   'kills': 9,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5456166229,
#   'party_size': 2,
#   'player_slot': 128,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1591412694,
#   'version': None},
#  {'assists': 12,
#   'deaths': 5,
#   'duration': 2418,
#   'game_mode': 22,
#   'hero_id': 47,
#   'kills': 9,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5456114375,
#   'party_size': 2,
#   'player_slot': 0,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1591409547,
#   'version': None},
#  {'assists': 5,
#   'deaths': 9,
#   'duration': 2674,
#   'game_mode': 22,
#   'hero_id': 47,
#   'kills': 8,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5452816469,
#   'party_size': 3,
#   'player_slot': 129,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1591245547,
#   'version': None},
#  {'assists': 5,
#   'deaths': 18,
#   'duration': 2546,
#   'game_mode': 22,
#   'hero_id': 50,
#   'kills': 1,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5452771998,
#   'party_size': 2,
#   'player_slot': 3,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1591242467,
#   'version': 21},
#  {'assists': 8,
#   'deaths': 21,
#   'duration': 2481,
#   'game_mode': 22,
#   'hero_id': 50,
#   'kills': 4,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5452730496,
#   'party_size': 2,
#   'player_slot': 130,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1591239598,
#   'version': None},
#  {'assists': 10,
#   'deaths': 6,
#   'duration': 3209,
#   'game_mode': 22,
#   'hero_id': 112,
#   'kills': 2,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5451070585,
#   'party_size': 2,
#   'player_slot': 1,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1591155469,
#   'version': None},
#  {'assists': 23,
#   'deaths': 7,
#   'duration': 2479,
#   'game_mode': 22,
#   'hero_id': 62,
#   'kills': 8,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5451028001,
#   'party_size': 2,
#   'player_slot': 131,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1591152550,
#   'version': None},
#  {'assists': 9,
#   'deaths': 6,
#   'duration': 2626,
#   'game_mode': 22,
#   'hero_id': 35,
#   'kills': 6,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5443280638,
#   'party_size': 3,
#   'player_slot': 2,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1590813446,
#   'version': None},
#  {'assists': 27,
#   'deaths': 3,
#   'duration': 2985,
#   'game_mode': 22,
#   'hero_id': 39,
#   'kills': 18,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5443213162,
#   'party_size': 3,
#   'player_slot': 129,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1590809896,
#   'version': None},
#  {'assists': 21,
#   'deaths': 13,
#   'duration': 3618,
#   'game_mode': 22,
#   'hero_id': 30,
#   'kills': 11,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5443139831,
#   'party_size': 3,
#   'player_slot': 128,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1590805912,
#   'version': None},
#  {'assists': 9,
#   'deaths': 2,
#   'duration': 2487,
#   'game_mode': 22,
#   'hero_id': 35,
#   'kills': 13,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5437600091,
#   'party_size': 2,
#   'player_slot': 131,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1590552838,
#   'version': None},
#  {'assists': 4,
#   'deaths': 9,
#   'duration': 2231,
#   'game_mode': 22,
#   'hero_id': 35,
#   'kills': 5,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5437558302,
#   'party_size': 2,
#   'player_slot': 3,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1590550259,
#   'version': None},
#  {'assists': 26,
#   'deaths': 4,
#   'duration': 2810,
#   'game_mode': 22,
#   'hero_id': 64,
#   'kills': 6,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5434011534,
#   'party_size': 2,
#   'player_slot': 3,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1590378454,
#   'version': None},
#  {'assists': 9,
#   'deaths': 11,
#   'duration': 2667,
#   'game_mode': 22,
#   'hero_id': 39,
#   'kills': 13,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5433966890,
#   'party_size': 2,
#   'player_slot': 0,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1590375351,
#   'version': None},
#  {'assists': 29,
#   'deaths': 7,
#   'duration': 2991,
#   'game_mode': 22,
#   'hero_id': 22,
#   'kills': 17,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5432167978,
#   'party_size': 2,
#   'player_slot': 129,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1590293595,
#   'version': None},
#  {'assists': 22,
#   'deaths': 8,
#   'duration': 3353,
#   'game_mode': 22,
#   'hero_id': 39,
#   'kills': 9,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5430370163,
#   'party_size': 2,
#   'player_slot': 3,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1590210147,
#   'version': None},
#  {'assists': 11,
#   'deaths': 12,
#   'duration': 4028,
#   'game_mode': 22,
#   'hero_id': 35,
#   'kills': 13,
#   'leaver_status': 0,
#   'lobby_type': 7,
#   'match_id': 5430106767,
#   'party_size': 1,
#   'player_slot': 132,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1590191993,
#   'version': None},
#  {'assists': 17,
#   'deaths': 11,
#   'duration': 2769,
#   'game_mode': 22,
#   'hero_id': 84,
#   'kills': 2,
#   'leaver_status': 0,
#   'lobby_type': 7,
#   'match_id': 5430062688,
#   'party_size': 1,
#   'player_slot': 131,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1590188431,
#   'version': None},
#  {'assists': 2,
#   'deaths': 5,
#   'duration': 1703,
#   'game_mode': 22,
#   'hero_id': 30,
#   'kills': 2,
#   'leaver_status': 0,
#   'lobby_type': 7,
#   'match_id': 5430031879,
#   'party_size': 1,
#   'player_slot': 131,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1590186184,
#   'version': None},
#  {'assists': 16,
#   'deaths': 0,
#   'duration': 2096,
#   'game_mode': 22,
#   'hero_id': 64,
#   'kills': 12,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5428725780,
#   'party_size': 2,
#   'player_slot': 0,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1590126877,
#   'version': None},
#  {'assists': 22,
#   'deaths': 10,
#   'duration': 4029,
#   'game_mode': 22,
#   'hero_id': 35,
#   'kills': 15,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5428662452,
#   'party_size': 2,
#   'player_slot': 3,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1590122369,
#   'version': None},
#  {'assists': 6,
#   'deaths': 5,
#   'duration': 2226,
#   'game_mode': 22,
#   'hero_id': 84,
#   'kills': 3,
#   'leaver_status': 0,
#   'lobby_type': 7,
#   'match_id': 5428517062,
#   'party_size': 1,
#   'player_slot': 129,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1590111069,
#   'version': None},
#  {'assists': 13,
#   'deaths': 9,
#   'duration': 2964,
#   'game_mode': 22,
#   'hero_id': 32,
#   'kills': 5,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5427021801,
#   'party_size': 2,
#   'player_slot': 131,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1590032803,
#   'version': None},
#  {'assists': 3,
#   'deaths': 7,
#   'duration': 2026,
#   'game_mode': 22,
#   'hero_id': 62,
#   'kills': 2,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5423790486,
#   'party_size': 2,
#   'player_slot': 0,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1589857491,
#   'version': None},
#  {'assists': 11,
#   'deaths': 10,
#   'duration': 2262,
#   'game_mode': 22,
#   'hero_id': 32,
#   'kills': 16,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5422088575,
#   'party_size': 2,
#   'player_slot': 131,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1589777463,
#   'version': None},
#  {'assists': 4,
#   'deaths': 4,
#   'duration': 2027,
#   'game_mode': 22,
#   'hero_id': 22,
#   'kills': 4,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5422054317,
#   'party_size': 2,
#   'player_slot': 128,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1589775094,
#   'version': 21},
#  {'assists': 5,
#   'deaths': 8,
#   'duration': 3149,
#   'game_mode': 22,
#   'hero_id': 26,
#   'kills': 2,
#   'leaver_status': 4,
#   'lobby_type': 0,
#   'match_id': 5421728403,
#   'party_size': 1,
#   'player_slot': 130,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1589752808,
#   'version': None},
#  {'assists': 24,
#   'deaths': 5,
#   'duration': 2338,
#   'game_mode': 22,
#   'hero_id': 84,
#   'kills': 4,
#   'leaver_status': 0,
#   'lobby_type': 7,
#   'match_id': 5421661808,
#   'party_size': 1,
#   'player_slot': 132,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1589749532,
#   'version': 21},
#  {'assists': 19,
#   'deaths': 6,
#   'duration': 2311,
#   'game_mode': 22,
#   'hero_id': 36,
#   'kills': 9,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5417798886,
#   'party_size': 2,
#   'player_slot': 131,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1589603561,
#   'version': None},
#  {'assists': 20,
#   'deaths': 9,
#   'duration': 2666,
#   'game_mode': 22,
#   'hero_id': 84,
#   'kills': 10,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5417742481,
#   'party_size': 2,
#   'player_slot': 130,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1589600236,
#   'version': None},
#  {'assists': 4,
#   'deaths': 9,
#   'duration': 2081,
#   'game_mode': 22,
#   'hero_id': 94,
#   'kills': 1,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5415949742,
#   'party_size': 2,
#   'player_slot': 0,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1589518153,
#   'version': None},
#  {'assists': 16,
#   'deaths': 10,
#   'duration': 3051,
#   'game_mode': 22,
#   'hero_id': 23,
#   'kills': 16,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5415900767,
#   'party_size': 2,
#   'player_slot': 131,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1589514733,
#   'version': None},
#  {'assists': 6,
#   'deaths': 6,
#   'duration': 1976,
#   'game_mode': 22,
#   'hero_id': 102,
#   'kills': 2,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5412301445,
#   'party_size': 3,
#   'player_slot': 0,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1589336248,
#   'version': None},
#  {'assists': 8,
#   'deaths': 11,
#   'duration': 3152,
#   'game_mode': 22,
#   'hero_id': 68,
#   'kills': 1,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5408899242,
#   'party_size': None,
#   'player_slot': 129,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1589170200,
#   'version': None},
#  {'assists': 6,
#   'deaths': 12,
#   'duration': 2505,
#   'game_mode': 22,
#   'hero_id': 47,
#   'kills': 5,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5408851951,
#   'party_size': 2,
#   'player_slot': 130,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1589166838,
#   'version': None},
#  {'assists': 20,
#   'deaths': 5,
#   'duration': 2525,
#   'game_mode': 22,
#   'hero_id': 50,
#   'kills': 5,
#   'leaver_status': 0,
#   'lobby_type': 7,
#   'match_id': 5408802755,
#   'party_size': 1,
#   'player_slot': 0,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1589163303,
#   'version': None},
#  {'assists': 2,
#   'deaths': 9,
#   'duration': 2055,
#   'game_mode': 22,
#   'hero_id': 99,
#   'kills': 10,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5406926368,
#   'party_size': 3,
#   'player_slot': 130,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1589084038,
#   'version': 21},
#  {'assists': 0,
#   'deaths': 0,
#   'duration': 770,
#   'game_mode': 22,
#   'hero_id': 35,
#   'kills': 0,
#   'leaver_status': 1,
#   'lobby_type': 0,
#   'match_id': 5406907924,
#   'party_size': 3,
#   'player_slot': 0,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1589082972,
#   'version': None},
#  {'assists': 17,
#   'deaths': 0,
#   'duration': 1817,
#   'game_mode': 22,
#   'hero_id': 108,
#   'kills': 14,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5406864063,
#   'party_size': 3,
#   'player_slot': 2,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1589080417,
#   'version': None},
#  {'assists': 21,
#   'deaths': 6,
#   'duration': 2599,
#   'game_mode': 22,
#   'hero_id': 30,
#   'kills': 8,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5406812004,
#   'party_size': 2,
#   'player_slot': 131,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1589077402,
#   'version': 21},
#  {'assists': 13,
#   'deaths': 12,
#   'duration': 2798,
#   'game_mode': 22,
#   'hero_id': 64,
#   'kills': 1,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5406627736,
#   'party_size': 2,
#   'player_slot': 129,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1589064660,
#   'version': 21},
#  {'assists': 17,
#   'deaths': 10,
#   'duration': 3526,
#   'game_mode': 22,
#   'hero_id': 30,
#   'kills': 10,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5406558490,
#   'party_size': 2,
#   'player_slot': 132,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1589060612,
#   'version': None},
#  {'assists': 15,
#   'deaths': 12,
#   'duration': 2722,
#   'game_mode': 22,
#   'hero_id': 79,
#   'kills': 5,
#   'leaver_status': 0,
#   'lobby_type': 7,
#   'match_id': 5406492731,
#   'party_size': 1,
#   'player_slot': 1,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1589057327,
#   'version': None},
#  {'assists': 20,
#   'deaths': 10,
#   'duration': 2629,
#   'game_mode': 22,
#   'hero_id': 32,
#   'kills': 14,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5404919662,
#   'party_size': 2,
#   'player_slot': 3,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1588995952,
#   'version': None},
#  {'assists': 10,
#   'deaths': 13,
#   'duration': 3192,
#   'game_mode': 22,
#   'hero_id': 35,
#   'kills': 20,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5401310552,
#   'party_size': 2,
#   'player_slot': 128,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1588826627,
#   'version': None},
#  {'assists': 5,
#   'deaths': 10,
#   'duration': 2174,
#   'game_mode': 22,
#   'hero_id': 47,
#   'kills': 14,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5401268783,
#   'party_size': 2,
#   'player_slot': 130,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1588823856,
#   'version': None},
#  {'assists': 36,
#   'deaths': 16,
#   'duration': 4909,
#   'game_mode': 22,
#   'hero_id': 68,
#   'kills': 17,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5399514433,
#   'party_size': 3,
#   'player_slot': 130,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1588742694,
#   'version': None},
#  {'assists': 1,
#   'deaths': 5,
#   'duration': 879,
#   'game_mode': 22,
#   'hero_id': 38,
#   'kills': 4,
#   'leaver_status': 1,
#   'lobby_type': 0,
#   'match_id': 5399495998,
#   'party_size': 3,
#   'player_slot': 128,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1588741512,
#   'version': 21},
#  {'assists': 10,
#   'deaths': 6,
#   'duration': 2817,
#   'game_mode': 22,
#   'hero_id': 35,
#   'kills': 10,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5399448676,
#   'party_size': 2,
#   'player_slot': 128,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1588738322,
#   'version': 21},
#  {'assists': 9,
#   'deaths': 6,
#   'duration': 1662,
#   'game_mode': 22,
#   'hero_id': 32,
#   'kills': 4,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5399419279,
#   'party_size': 2,
#   'player_slot': 3,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1588736209,
#   'version': None},
#  {'assists': 5,
#   'deaths': 4,
#   'duration': 2311,
#   'game_mode': 22,
#   'hero_id': 68,
#   'kills': 4,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5395546243,
#   'party_size': 2,
#   'player_slot': 130,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1588565960,
#   'version': None},
#  {'assists': 5,
#   'deaths': 5,
#   'duration': 2225,
#   'game_mode': 22,
#   'hero_id': 68,
#   'kills': 7,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5395500433,
#   'party_size': 2,
#   'player_slot': 128,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1588563222,
#   'version': 21},
#  {'assists': 6,
#   'deaths': 10,
#   'duration': 2030,
#   'game_mode': 22,
#   'hero_id': 84,
#   'kills': 1,
#   'leaver_status': 0,
#   'lobby_type': 7,
#   'match_id': 5395232383,
#   'party_size': 2,
#   'player_slot': 3,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1588545261,
#   'version': 21},
#  {'assists': 10,
#   'deaths': 6,
#   'duration': 3029,
#   'game_mode': 22,
#   'hero_id': 50,
#   'kills': 2,
#   'leaver_status': 0,
#   'lobby_type': 7,
#   'match_id': 5395166001,
#   'party_size': 1,
#   'player_slot': 128,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1588541438,
#   'version': None},
#  {'assists': 10,
#   'deaths': 13,
#   'duration': 2893,
#   'game_mode': 22,
#   'hero_id': 50,
#   'kills': 0,
#   'leaver_status': 0,
#   'lobby_type': 7,
#   'match_id': 5395098690,
#   'party_size': 1,
#   'player_slot': 0,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1588538250,
#   'version': None},
#  {'assists': 33,
#   'deaths': 12,
#   'duration': 3181,
#   'game_mode': 22,
#   'hero_id': 50,
#   'kills': 7,
#   'leaver_status': 0,
#   'lobby_type': 7,
#   'match_id': 5393198906,
#   'party_size': 1,
#   'player_slot': 1,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1588461832,
#   'version': None},
#  {'assists': 6,
#   'deaths': 4,
#   'duration': 1554,
#   'game_mode': 22,
#   'hero_id': 16,
#   'kills': 8,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5391412198,
#   'party_size': 3,
#   'player_slot': 131,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1588395943,
#   'version': None},
#  {'assists': 20,
#   'deaths': 11,
#   'duration': 3203,
#   'game_mode': 22,
#   'hero_id': 50,
#   'kills': 3,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5391346375,
#   'party_size': 3,
#   'player_slot': 3,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1588392352,
#   'version': None},
#  {'assists': 6,
#   'deaths': 3,
#   'duration': 2865,
#   'game_mode': 22,
#   'hero_id': 35,
#   'kills': 8,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5389305736,
#   'party_size': 3,
#   'player_slot': 2,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1588308845,
#   'version': None},
#  {'assists': 14,
#   'deaths': 8,
#   'duration': 2912,
#   'game_mode': 22,
#   'hero_id': 35,
#   'kills': 10,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5389247677,
#   'party_size': 2,
#   'player_slot': 1,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1588305599,
#   'version': 21},
#  {'assists': 23,
#   'deaths': 3,
#   'duration': 1728,
#   'game_mode': 22,
#   'hero_id': 32,
#   'kills': 17,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5387339337,
#   'party_size': 3,
#   'player_slot': 132,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1588222610,
#   'version': None},
#  {'assists': 22,
#   'deaths': 7,
#   'duration': 2864,
#   'game_mode': 22,
#   'hero_id': 84,
#   'kills': 9,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5387291132,
#   'party_size': 3,
#   'player_slot': 132,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1588219298,
#   'version': None},
#  {'assists': 6,
#   'deaths': 11,
#   'duration': 3827,
#   'game_mode': 22,
#   'hero_id': 6,
#   'kills': 13,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5385479458,
#   'party_size': 3,
#   'player_slot': 3,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1588137067,
#   'version': None},
#  {'assists': 3,
#   'deaths': 7,
#   'duration': 3033,
#   'game_mode': 22,
#   'hero_id': 6,
#   'kills': 12,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5385424362,
#   'party_size': 5,
#   'player_slot': 130,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1588133506,
#   'version': None},
#  {'assists': 3,
#   'deaths': 9,
#   'duration': 2531,
#   'game_mode': 22,
#   'hero_id': 35,
#   'kills': 9,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5385378948,
#   'party_size': 2,
#   'player_slot': 129,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1588130440,
#   'version': None},
#  {'assists': 24,
#   'deaths': 7,
#   'duration': 3931,
#   'game_mode': 22,
#   'hero_id': 22,
#   'kills': 13,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5383626706,
#   'party_size': 3,
#   'player_slot': 132,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1588051800,
#   'version': None},
#  {'assists': 9,
#   'deaths': 16,
#   'duration': 3869,
#   'game_mode': 22,
#   'hero_id': 26,
#   'kills': 5,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5383556996,
#   'party_size': 3,
#   'player_slot': 129,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1588047518,
#   'version': 21},
#  {'assists': 16,
#   'deaths': 7,
#   'duration': 2804,
#   'game_mode': 22,
#   'hero_id': 63,
#   'kills': 11,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5383507488,
#   'party_size': 3,
#   'player_slot': 129,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1588044317,
#   'version': None},
#  {'assists': 13,
#   'deaths': 2,
#   'duration': 1798,
#   'game_mode': 22,
#   'hero_id': 35,
#   'kills': 17,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5379585093,
#   'party_size': 3,
#   'player_slot': 0,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1587878687,
#   'version': None},
#  {'assists': 19,
#   'deaths': 8,
#   'duration': 2772,
#   'game_mode': 22,
#   'hero_id': 47,
#   'kills': 10,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5379527584,
#   'party_size': 3,
#   'player_slot': 128,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1587875557,
#   'version': None},
#  {'assists': 15,
#   'deaths': 12,
#   'duration': 3706,
#   'game_mode': 22,
#   'hero_id': 6,
#   'kills': 11,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5379455671,
#   'party_size': 2,
#   'player_slot': 3,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1587871368,
#   'version': None},
#  {'assists': 14,
#   'deaths': 6,
#   'duration': 1830,
#   'game_mode': 22,
#   'hero_id': 26,
#   'kills': 5,
#   'leaver_status': 0,
#   'lobby_type': 7,
#   'match_id': 5379223871,
#   'party_size': 1,
#   'player_slot': 3,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1587855907,
#   'version': None},
#  {'assists': 27,
#   'deaths': 11,
#   'duration': 4107,
#   'game_mode': 22,
#   'hero_id': 50,
#   'kills': 2,
#   'leaver_status': 0,
#   'lobby_type': 7,
#   'match_id': 5379136852,
#   'party_size': 1,
#   'player_slot': 131,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1587851133,
#   'version': None},
#  {'assists': 20,
#   'deaths': 5,
#   'duration': 2082,
#   'game_mode': 22,
#   'hero_id': 84,
#   'kills': 4,
#   'leaver_status': 0,
#   'lobby_type': 7,
#   'match_id': 5379076187,
#   'party_size': 1,
#   'player_slot': 132,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1587848381,
#   'version': 21},
#  {'assists': 24,
#   'deaths': 15,
#   'duration': 4550,
#   'game_mode': 22,
#   'hero_id': 59,
#   'kills': 12,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5377318764,
#   'party_size': 2,
#   'player_slot': 130,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1587788041,
#   'version': None},
#  {'assists': 18,
#   'deaths': 4,
#   'duration': 3468,
#   'game_mode': 22,
#   'hero_id': 35,
#   'kills': 25,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5377246170,
#   'party_size': 2,
#   'player_slot': 128,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1587783983,
#   'version': None},
#  {'assists': 13,
#   'deaths': 11,
#   'duration': 3355,
#   'game_mode': 22,
#   'hero_id': 43,
#   'kills': 13,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5375274361,
#   'party_size': 2,
#   'player_slot': 0,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1587702177,
#   'version': 21},
#  {'assists': 6,
#   'deaths': 4,
#   'duration': 2338,
#   'game_mode': 22,
#   'hero_id': 35,
#   'kills': 4,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5375225631,
#   'party_size': 2,
#   'player_slot': 1,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1587698912,
#   'version': None},
#  {'assists': 17,
#   'deaths': 5,
#   'duration': 2407,
#   'game_mode': 22,
#   'hero_id': 128,
#   'kills': 1,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5375184156,
#   'party_size': 2,
#   'player_slot': 131,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1587696102,
#   'version': None},
#  {'assists': 15,
#   'deaths': 3,
#   'duration': 3136,
#   'game_mode': 22,
#   'hero_id': 35,
#   'kills': 11,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5371383510,
#   'party_size': 2,
#   'player_slot': 0,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1587531076,
#   'version': None},
#  {'assists': 9,
#   'deaths': 7,
#   'duration': 2247,
#   'game_mode': 22,
#   'hero_id': 47,
#   'kills': 15,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5367407600,
#   'party_size': 3,
#   'player_slot': 0,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1587358359,
#   'version': None},
#  {'assists': 20,
#   'deaths': 2,
#   'duration': 1672,
#   'game_mode': 22,
#   'hero_id': 84,
#   'kills': 4,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5367374531,
#   'party_size': 3,
#   'player_slot': 130,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1587356301,
#   'version': None},
#  {'assists': 28,
#   'deaths': 3,
#   'duration': 1975,
#   'game_mode': 22,
#   'hero_id': 50,
#   'kills': 6,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5367336299,
#   'party_size': 3,
#   'player_slot': 0,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1587353943,
#   'version': None},
#  {'assists': 2,
#   'deaths': 9,
#   'duration': 1489,
#   'game_mode': 22,
#   'hero_id': 50,
#   'kills': 3,
#   'leaver_status': 0,
#   'lobby_type': 7,
#   'match_id': 5367028289,
#   'party_size': 1,
#   'player_slot': 130,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1587332725,
#   'version': None},
#  {'assists': 14,
#   'deaths': 3,
#   'duration': 2639,
#   'game_mode': 22,
#   'hero_id': 26,
#   'kills': 8,
#   'leaver_status': 0,
#   'lobby_type': 7,
#   'match_id': 5366951011,
#   'party_size': 1,
#   'player_slot': 2,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1587329111,
#   'version': None},
#  {'assists': 7,
#   'deaths': 10,
#   'duration': 2743,
#   'game_mode': 22,
#   'hero_id': 101,
#   'kills': 3,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5365161200,
#   'party_size': 2,
#   'player_slot': 2,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1587270715,
#   'version': None},
#  {'assists': 5,
#   'deaths': 8,
#   'duration': 2400,
#   'game_mode': 22,
#   'hero_id': 35,
#   'kills': 7,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5365103180,
#   'party_size': 2,
#   'player_slot': 0,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1587267740,
#   'version': None},
#  {'assists': 10,
#   'deaths': 6,
#   'duration': 2798,
#   'game_mode': 22,
#   'hero_id': 128,
#   'kills': 11,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5365042547,
#   'party_size': 2,
#   'player_slot': 1,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1587264535,
#   'version': None},
#  {'assists': 23,
#   'deaths': 11,
#   'duration': 2427,
#   'game_mode': 22,
#   'hero_id': 64,
#   'kills': 8,
#   'leaver_status': 0,
#   'lobby_type': 7,
#   'match_id': 5364733954,
#   'party_size': 1,
#   'player_slot': 4,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1587246109,
#   'version': None},
#  {'assists': 9,
#   'deaths': 7,
#   'duration': 1827,
#   'game_mode': 22,
#   'hero_id': 26,
#   'kills': 3,
#   'leaver_status': 0,
#   'lobby_type': 7,
#   'match_id': 5364672936,
#   'party_size': 1,
#   'player_slot': 3,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1587243483,
#   'version': 21},
#  {'assists': 6,
#   'deaths': 4,
#   'duration': 2423,
#   'game_mode': 22,
#   'hero_id': 30,
#   'kills': 9,
#   'leaver_status': 0,
#   'lobby_type': 7,
#   'match_id': 5364590531,
#   'party_size': 1,
#   'player_slot': 0,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1587240269,
#   'version': None},
#  {'assists': 19,
#   'deaths': 7,
#   'duration': 2750,
#   'game_mode': 22,
#   'hero_id': 35,
#   'kills': 20,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5362956709,
#   'party_size': 2,
#   'player_slot': 131,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1587190632,
#   'version': None},
#  {'assists': 23,
#   'deaths': 4,
#   'duration': 2458,
#   'game_mode': 22,
#   'hero_id': 26,
#   'kills': 12,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5362894361,
#   'party_size': 2,
#   'player_slot': 0,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1587187797,
#   'version': None},
#  {'assists': 9,
#   'deaths': 8,
#   'duration': 1570,
#   'game_mode': 22,
#   'hero_id': 59,
#   'kills': 24,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5362851543,
#   'party_size': 2,
#   'player_slot': 1,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1587185723,
#   'version': None},
#  {'assists': 4,
#   'deaths': 2,
#   'duration': 2047,
#   'game_mode': 22,
#   'hero_id': 89,
#   'kills': 4,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5362798553,
#   'party_size': 2,
#   'player_slot': 0,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1587182904,
#   'version': None},
#  {'assists': 2,
#   'deaths': 9,
#   'duration': 1888,
#   'game_mode': 22,
#   'hero_id': 43,
#   'kills': 4,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5362752192,
#   'party_size': 2,
#   'player_slot': 131,
#   'radiant_win': True,
#   'skill': 1,
#   'start_time': 1587180142,
#   'version': 21},
#  {'assists': 15,
#   'deaths': 1,
#   'duration': 1858,
#   'game_mode': 22,
#   'hero_id': 35,
#   'kills': 17,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5360674519,
#   'party_size': 2,
#   'player_slot': 131,
#   'radiant_win': False,
#   'skill': 1,
#   'start_time': 1587098176,
#   'version': 21},
#  {'assists': 9,
#   'deaths': 7,
#   'duration': 1889,
#   'game_mode': 22,
#   'hero_id': 32,
#   'kills': 6,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 5360636927,
#   'party_size': 2,
# ...
#   'deaths': 11,
#   'duration': 2571,
#   'game_mode': 1,
#   'hero_id': 4,
#   'kills': 5,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 89698240,
#   'party_size': None,
#   'player_slot': 3,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1356928047,
#   'version': None},
#  {'assists': 2,
#   'deaths': 5,
#   'duration': 1821,
#   'game_mode': 1,
#   'hero_id': 6,
#   'kills': 2,
#   'leaver_status': 1,
#   'lobby_type': 0,
#   'match_id': 89307616,
#   'party_size': None,
#   'player_slot': 129,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1356880396,
#   'version': None},
#  {'assists': 5,
#   'deaths': 13,
#   'duration': 2230,
#   'game_mode': 1,
#   'hero_id': 71,
#   'kills': 4,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 89277719,
#   'party_size': None,
#   'player_slot': 129,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1356877695,
#   'version': None},
#  {'assists': 11,
#   'deaths': 11,
#   'duration': 3157,
#   'game_mode': 1,
#   'hero_id': 32,
#   'kills': 10,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 89073343,
#   'party_size': None,
#   'player_slot': 1,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1356855848,
#   'version': None},
#  {'assists': 4,
#   'deaths': 9,
#   'duration': 2289,
#   'game_mode': 1,
#   'hero_id': 56,
#   'kills': 2,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 89052610,
#   'party_size': None,
#   'player_slot': 1,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1356853041,
#   'version': None},
#  {'assists': 7,
#   'deaths': 6,
#   'duration': 2428,
#   'game_mode': 1,
#   'hero_id': 71,
#   'kills': 3,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 89033238,
#   'party_size': None,
#   'player_slot': 129,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1356850078,
#   'version': None},
#  {'assists': 16,
#   'deaths': 6,
#   'duration': 4067,
#   'game_mode': 1,
#   'hero_id': 4,
#   'kills': 5,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 89006285,
#   'party_size': None,
#   'player_slot': 3,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1356845350,
#   'version': None},
#  {'assists': 5,
#   'deaths': 6,
#   'duration': 2335,
#   'game_mode': 1,
#   'hero_id': 6,
#   'kills': 4,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 88570621,
#   'party_size': None,
#   'player_slot': 132,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1356791000,
#   'version': None},
#  {'assists': 2,
#   'deaths': 8,
#   'duration': 2661,
#   'game_mode': 1,
#   'hero_id': 32,
#   'kills': 1,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 88538108,
#   'party_size': None,
#   'player_slot': 132,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1356787950,
#   'version': None},
#  {'assists': 5,
#   'deaths': 5,
#   'duration': 2068,
#   'game_mode': 1,
#   'hero_id': 40,
#   'kills': 3,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 87892543,
#   'party_size': None,
#   'player_slot': 131,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1356706885,
#   'version': None},
#  {'assists': 5,
#   'deaths': 8,
#   'duration': 2438,
#   'game_mode': 1,
#   'hero_id': 56,
#   'kills': 3,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 87862376,
#   'party_size': None,
#   'player_slot': 131,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1356704147,
#   'version': None},
#  {'assists': 10,
#   'deaths': 4,
#   'duration': 2325,
#   'game_mode': 1,
#   'hero_id': 6,
#   'kills': 2,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 87833708,
#   'party_size': None,
#   'player_slot': 131,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1356701432,
#   'version': None},
#  {'assists': 7,
#   'deaths': 15,
#   'duration': 3964,
#   'game_mode': 1,
#   'hero_id': 41,
#   'kills': 4,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 87211186,
#   'party_size': None,
#   'player_slot': 4,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1356619573,
#   'version': None},
#  {'assists': 11,
#   'deaths': 9,
#   'duration': 2396,
#   'game_mode': 1,
#   'hero_id': 40,
#   'kills': 5,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 87122744,
#   'party_size': None,
#   'player_slot': 131,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1356611172,
#   'version': None},
#  {'assists': 1,
#   'deaths': 8,
#   'duration': 1887,
#   'game_mode': 1,
#   'hero_id': 32,
#   'kills': 2,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 87085944,
#   'party_size': None,
#   'player_slot': 129,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1356607215,
#   'version': None},
#  {'assists': 6,
#   'deaths': 6,
#   'duration': 2110,
#   'game_mode': 1,
#   'hero_id': 6,
#   'kills': 2,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 86318806,
#   'party_size': None,
#   'player_slot': 4,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1356504918,
#   'version': None},
#  {'assists': 6,
#   'deaths': 7,
#   'duration': 2175,
#   'game_mode': 1,
#   'hero_id': 6,
#   'kills': 4,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 85831484,
#   'party_size': None,
#   'player_slot': 131,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1356437745,
#   'version': None},
#  {'assists': 12,
#   'deaths': 13,
#   'duration': 3419,
#   'game_mode': 1,
#   'hero_id': 40,
#   'kills': 0,
#   'leaver_status': 1,
#   'lobby_type': 0,
#   'match_id': 85776304,
#   'party_size': None,
#   'player_slot': 1,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1356431534,
#   'version': None},
#  {'assists': 5,
#   'deaths': 7,
#   'duration': 1895,
#   'game_mode': 1,
#   'hero_id': 32,
#   'kills': 1,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 85755242,
#   'party_size': None,
#   'player_slot': 2,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1356428785,
#   'version': None},
#  {'assists': 7,
#   'deaths': 5,
#   'duration': 1793,
#   'game_mode': 1,
#   'hero_id': 62,
#   'kills': 2,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 85738086,
#   'party_size': None,
#   'player_slot': 130,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1356426390,
#   'version': None},
#  {'assists': 3,
#   'deaths': 5,
#   'duration': 2430,
#   'game_mode': 1,
#   'hero_id': 32,
#   'kills': 5,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 85716284,
#   'party_size': None,
#   'player_slot': 1,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1356423074,
#   'version': None},
#  {'assists': 4,
#   'deaths': 9,
#   'duration': 1950,
#   'game_mode': 1,
#   'hero_id': 32,
#   'kills': 3,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 85677835,
#   'party_size': None,
#   'player_slot': 3,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1356416207,
#   'version': None},
#  {'assists': 1,
#   'deaths': 2,
#   'duration': 1652,
#   'game_mode': 1,
#   'hero_id': 6,
#   'kills': 0,
#   'leaver_status': 1,
#   'lobby_type': 0,
#   'match_id': 85671919,
#   'party_size': None,
#   'player_slot': 4,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1356414991,
#   'version': None},
#  {'assists': 0,
#   'deaths': 0,
#   'duration': 567,
#   'game_mode': 1,
#   'hero_id': 6,
#   'kills': 0,
#   'leaver_status': 2,
#   'lobby_type': 0,
#   'match_id': 85665254,
#   'party_size': None,
#   'player_slot': 0,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1356413606,
#   'version': None},
#  {'assists': 9,
#   'deaths': 13,
#   'duration': 2295,
#   'game_mode': 1,
#   'hero_id': 6,
#   'kills': 2,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 84348273,
#   'party_size': None,
#   'player_slot': 4,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1356254490,
#   'version': None},
#  {'assists': 4,
#   'deaths': 2,
#   'duration': 2417,
#   'game_mode': 1,
#   'hero_id': 4,
#   'kills': 2,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 81331010,
#   'party_size': None,
#   'player_slot': 3,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1355926638,
#   'version': None},
#  {'assists': 7,
#   'deaths': 10,
#   'duration': 2220,
#   'game_mode': 1,
#   'hero_id': 62,
#   'kills': 0,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 81267113,
#   'party_size': None,
#   'player_slot': 4,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1355919854,
#   'version': None},
#  {'assists': 5,
#   'deaths': 12,
#   'duration': 2446,
#   'game_mode': 1,
#   'hero_id': 62,
#   'kills': 1,
#   'leaver_status': 1,
#   'lobby_type': 0,
#   'match_id': 80898577,
#   'party_size': None,
#   'player_slot': 4,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1355854802,
#   'version': None},
#  {'assists': 0,
#   'deaths': 0,
#   'duration': 619,
#   'game_mode': 1,
#   'hero_id': 62,
#   'kills': 0,
#   'leaver_status': 1,
#   'lobby_type': 0,
#   'match_id': 80693488,
#   'party_size': None,
#   'player_slot': 128,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1355834601,
#   'version': None},
#  {'assists': 8,
#   'deaths': 11,
#   'duration': 2336,
#   'game_mode': 1,
#   'hero_id': 31,
#   'kills': 4,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 79344989,
#   'party_size': None,
#   'player_slot': 131,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1355645520,
#   'version': None},
#  {'assists': 6,
#   'deaths': 12,
#   'duration': 2927,
#   'game_mode': 1,
#   'hero_id': 32,
#   'kills': 3,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 79319022,
#   'party_size': None,
#   'player_slot': 3,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1355641968,
#   'version': None},
#  {'assists': 4,
#   'deaths': 11,
#   'duration': 2290,
#   'game_mode': 1,
#   'hero_id': 6,
#   'kills': 1,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 78865675,
#   'party_size': None,
#   'player_slot': 1,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1355582519,
#   'version': None},
#  {'assists': 2,
#   'deaths': 10,
#   'duration': 2054,
#   'game_mode': 1,
#   'hero_id': 63,
#   'kills': 0,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 78838297,
#   'party_size': None,
#   'player_slot': 130,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1355580070,
#   'version': None},
#  {'assists': 3,
#   'deaths': 5,
#   'duration': 1884,
#   'game_mode': 1,
#   'hero_id': 6,
#   'kills': 3,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 78812035,
#   'party_size': None,
#   'player_slot': 1,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1355577698,
#   'version': None},
#  {'assists': 5,
#   'deaths': 5,
#   'duration': 2725,
#   'game_mode': 1,
#   'hero_id': 56,
#   'kills': 0,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 78684384,
#   'party_size': None,
#   'player_slot': 131,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1355564919,
#   'version': None},
#  {'assists': 5,
#   'deaths': 6,
#   'duration': 1786,
#   'game_mode': 1,
#   'hero_id': 6,
#   'kills': 2,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 78638086,
#   'party_size': None,
#   'player_slot': 132,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1355558969,
#   'version': None},
#  {'assists': 3,
#   'deaths': 10,
#   'duration': 2484,
#   'game_mode': 1,
#   'hero_id': 47,
#   'kills': 8,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 78288006,
#   'party_size': None,
#   'player_slot': 130,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1355505578,
#   'version': None},
#  {'assists': 4,
#   'deaths': 0,
#   'duration': 1376,
#   'game_mode': 1,
#   'hero_id': 56,
#   'kills': 0,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 78259334,
#   'party_size': None,
#   'player_slot': 3,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1355503105,
#   'version': None},
#  {'assists': 11,
#   'deaths': 7,
#   'duration': 2227,
#   'game_mode': 1,
#   'hero_id': 40,
#   'kills': 4,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 78226467,
#   'party_size': None,
#   'player_slot': 3,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1355500289,
#   'version': None},
#  {'assists': 5,
#   'deaths': 8,
#   'duration': 2273,
#   'game_mode': 1,
#   'hero_id': 6,
#   'kills': 2,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 78195737,
#   'party_size': None,
#   'player_slot': 131,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1355497572,
#   'version': None},
#  {'assists': 1,
#   'deaths': 2,
#   'duration': 1350,
#   'game_mode': 1,
#   'hero_id': 59,
#   'kills': 0,
#   'leaver_status': 1,
#   'lobby_type': 0,
#   'match_id': 77719849,
#   'party_size': None,
#   'player_slot': 3,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1355423830,
#   'version': None},
#  {'assists': 14,
#   'deaths': 3,
#   'duration': 2197,
#   'game_mode': 1,
#   'hero_id': 6,
#   'kills': 3,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 77696174,
#   'party_size': None,
#   'player_slot': 130,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1355421207,
#   'version': None},
#  {'assists': 1,
#   'deaths': 2,
#   'duration': 2043,
#   'game_mode': 1,
#   'hero_id': 73,
#   'kills': 0,
#   'leaver_status': 3,
#   'lobby_type': 0,
#   'match_id': 77686289,
#   'party_size': None,
#   'player_slot': 132,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1355420168,
#   'version': None},
#  {'assists': 10,
#   'deaths': 8,
#   'duration': 2382,
#   'game_mode': 1,
#   'hero_id': 6,
#   'kills': 7,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 77051823,
#   'party_size': None,
#   'player_slot': 2,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1355321869,
#   'version': None},
#  {'assists': 13,
#   'deaths': 5,
#   'duration': 2844,
#   'game_mode': 1,
#   'hero_id': 6,
#   'kills': 18,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 77015855,
#   'party_size': None,
#   'player_slot': 131,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1355317628,
#   'version': None},
#  {'assists': 0,
#   'deaths': 4,
#   'duration': 1426,
#   'game_mode': 1,
#   'hero_id': 6,
#   'kills': 0,
#   'leaver_status': 1,
#   'lobby_type': 0,
#   'match_id': 76990778,
#   'party_size': None,
#   'player_slot': 128,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1355314499,
#   'version': None},
#  {'assists': 3,
#   'deaths': 4,
#   'duration': 1771,
#   'game_mode': 4,
#   'hero_id': 53,
#   'kills': 1,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 76971698,
#   'party_size': None,
#   'player_slot': 129,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1355312039,
#   'version': None},
#  {'assists': 5,
#   'deaths': 1,
#   'duration': 1339,
#   'game_mode': 1,
#   'hero_id': 6,
#   'kills': 9,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 76702786,
#   'party_size': None,
#   'player_slot': 132,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1355254848,
#   'version': None},
#  {'assists': 6,
#   'deaths': 12,
#   'duration': 2763,
#   'game_mode': 1,
#   'hero_id': 6,
#   'kills': 7,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 76670353,
#   'party_size': None,
#   'player_slot': 3,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1355250955,
#   'version': None},
#  {'assists': 3,
#   'deaths': 9,
#   'duration': 2778,
#   'game_mode': 1,
#   'hero_id': 6,
#   'kills': 8,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 76572654,
#   'party_size': None,
#   'player_slot': 2,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1355240202,
#   'version': None},
#  {'assists': 4,
#   'deaths': 16,
#   'duration': 2854,
#   'game_mode': 1,
#   'hero_id': 4,
#   'kills': 3,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 74806847,
#   'party_size': None,
#   'player_slot': 132,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1354967352,
#   'version': None},
#  {'assists': 5,
#   'deaths': 9,
#   'duration': 2216,
#   'game_mode': 4,
#   'hero_id': 63,
#   'kills': 3,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 74170846,
#   'party_size': 10,
#   'player_slot': 129,
#   'radiant_win': False,
#   'skill': None,
#   'start_time': 1354864825,
#   'version': None},
#  {'assists': 12,
#   'deaths': 4,
#   'duration': 2940,
#   'game_mode': 1,
#   'hero_id': 6,
#   'kills': 4,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 74139977,
#   'party_size': 10,
#   'player_slot': 2,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1354855827,
#   'version': None},
#  {'assists': 11,
#   'deaths': 5,
#   'duration': 2389,
#   'game_mode': 0,
#   'hero_id': 53,
#   'kills': 0,
#   'leaver_status': 0,
#   'lobby_type': 0,
#   'match_id': 32516647,
#   'party_size': None,
#   'player_slot': 4,
#   'radiant_win': True,
#   'skill': None,
#   'start_time': 1344829533,
#   'version': None}]
